# %% [markdown]
# ## Background:
#
# I created a [Social Media survey in REDCap](https://redcap.iths.org/surveys/?s=NP4ETD4X98KX3Y8W) that solicits questions about social media use as well as ADHD diagnostic outcomes. The survey is exploring a relationship between ADHD diagnosis seeking and use of TikTok. The TikTok algorithm pushes content into user's FYP that could potentially be an initial connnection with ADHD symptoms for many users. Relating or engaging with this content could push more additional content resulting in questions about one's own status as having clinical ADHD.
#
# ## Step 1: Clean my data using EDA techniques
# The first thing we need to have in mind when exploring data is why we are doing it. There are multiple reasons to explore a dataset, the main ones usually being:
#
# understanding your data before building an ML model
# analysis to uncover interesting patterns
# sheer curiosity
# Depending on your goal, the analysis can take slightly different forms, but the basic structure I use is this:
#
# - Loading libraries and data
# - Reading data documentation
# - Univariate data analysis
# - Bivariate data analysis
# - Multivariate data analysis
# - Insights and next steps

# %%
# Loading libraries and data
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load data 
df = pd.read_csv('/Users/jennyskytta/Downloads/SocialMediaSurvey_recode.csv', sep=',')

# look at the shape of data 
print(df.shape)
# check the top of the data 
df.head()
# Out:
# (35, 29)
#    Record ID Survey Timestamp use_any_social Washington_State Instagram  \
# 0          1    4/26/23 16:49            Yes              Yes       yes
# 1          2    4/26/23 16:43            Yes              Yes       yes
# 2          3              NaN            NaN              NaN        no
# 3          4    4/26/23 18:32            Yes              Yes       yes
# 4          5    4/26/23 20:38            Yes               No       yes
#
#   Snapchat Twitter BeReal TikTok Facebook  ... self_dx age_dx dx_lic  \
# 0      yes     yes     no    yes      yes  ...     Yes   28.0    Yes
# 1       no     yes     no     no       no  ...      No    NaN    NaN
# 2       no      no     no     no       no  ...     NaN    NaN    NaN
# 3       no      no     no     no       no  ...      No    NaN    NaN
# 4       no     yes     no    yes      yes  ...     Yes    NaN    NaN
#
#                                     dx_provider  \
# 0  Telehealth with provider  - location unknown
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                               led_to_dx without_wouldyou rx_for_dx  \
# 0  Web search of symptoms or experience              Yes       Yes
# 1                                   NaN              NaN       NaN
# 2                                   NaN              NaN       NaN
# 3                                   NaN              NaN       NaN
# 4                                   NaN              NaN       NaN
#
#                           rx_provider                             led_to_rx  \
# 0  Via Telehealth with local provider  Web search of symptoms or experience
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#     Complete?
# 0    Complete
# 1    Complete
# 2  Incomplete
# 3    Complete
# 4    Complete
#
# [5 rows x 29 columns]

# %%
# convert yes / no to 1 and 0 
df = df.replace(to_replace = "Yes", value = 1)
df = df.replace(to_replace = "no", value = 0)
df = df.replace(to_replace = "yes", value = 1)

# %%
# Specify the columns you want to convert
columns_to_convert = ['use_any_social', 'AvgHrsDay', 'believeADHD', 'age_dx', 'dx_lic']

# %%
# Create a dictionary with the desired data type for the selected columns
dtype_dict = {col: 'int64' for col in columns_to_convert}
df = df.astype(dtype_dict)

# %%
df.head()
# Out:
#    Record ID Survey Timestamp  use_any_social Washington_State  Instagram  \
# 0          1    4/26/23 16:49             1.0                1          1
# 1          2    4/26/23 16:43             1.0                1          1
# 2          3              NaN             NaN              NaN          0
# 3          4    4/26/23 18:32             1.0                1          1
# 4          5    4/26/23 20:38             1.0               No          1
#
#    Snapchat  Twitter  BeReal  TikTok  Facebook  ...  self_dx  age_dx dx_lic  \
# 0         1        1       0       1         1  ...        1    28.0    1.0
# 1         0        1       0       0         0  ...       No     NaN    NaN
# 2         0        0       0       0         0  ...      NaN     NaN    NaN
# 3         0        0       0       0         0  ...       No     NaN    NaN
# 4         0        1       0       1         1  ...        1     NaN    NaN
#
#                                     dx_provider  \
# 0  Telehealth with provider  - location unknown
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                               led_to_dx without_wouldyou rx_for_dx  \
# 0  Web search of symptoms or experience                1         1
# 1                                   NaN              NaN       NaN
# 2                                   NaN              NaN       NaN
# 3                                   NaN              NaN       NaN
# 4                                   NaN              NaN       NaN
#
#                           rx_provider                             led_to_rx  \
# 0  Via Telehealth with local provider  Web search of symptoms or experience
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#     Complete?
# 0    Complete
# 1    Complete
# 2  Incomplete
# 3    Complete
# 4    Complete
#
# [5 rows x 29 columns]

# %%
#Datatypes

df.dtypes
# Out:
# Record ID                int64
# Survey Timestamp        object
# use_any_social         float64
# Washington_State        object
# Instagram                int64
# Snapchat                 int64
# Twitter                  int64
# BeReal                   int64
# TikTok                   int64
# Facebook                 int64
# Nonelisted               int64
# NotOnAny                 int64
# SocMedMostUsed          object
# AvgHrsDay              float64
# Age                     object
# ADHDinFYP               object
# ADHDcontentsupports     object
# believeADHD            float64
# dxADHD                  object
# self_dx                 object
# age_dx                 float64
# dx_lic                 float64
# dx_provider             object
# led_to_dx               object
# without_wouldyou        object
# rx_for_dx               object
# rx_provider             object
# led_to_rx               object
# Complete?               object
# dtype: object

# %%
#Boxplot

df[['TikTok']].boxplot()
# Out:
# <AxesSubplot:>

# %%
#Correlation 

df.corr()
# Out:
#                 Record ID  use_any_social  Instagram  Snapchat   Twitter  \
# Record ID        1.000000             NaN   0.310694  0.198030  0.097183
# use_any_social        NaN             NaN        NaN       NaN       NaN
# Instagram        0.310694             NaN   1.000000  0.294174  0.377426
# Snapchat         0.198030             NaN   0.294174  1.000000  0.144338
# Twitter          0.097183             NaN   0.377426  0.144338  1.000000
# BeReal           0.291043             NaN   0.240192  0.204124  0.306413
# TikTok           0.199065             NaN   0.316973  0.206959  0.409673
# Facebook        -0.108616             NaN   0.150970  0.144338  0.166667
# Nonelisted            NaN             NaN        NaN       NaN       NaN
# NotOnAny              NaN             NaN        NaN       NaN       NaN
# AvgHrsDay        0.148845             NaN  -0.002261 -0.071768 -0.057635
# believeADHD           NaN             NaN        NaN       NaN       NaN
# age_dx          -0.361080             NaN  -0.069421  0.021608 -0.358992
# dx_lic                NaN             NaN        NaN       NaN       NaN
#
#                   BeReal    TikTok  Facebook  Nonelisted  NotOnAny  AvgHrsDay  \
# Record ID       0.291043  0.199065 -0.108616         NaN       NaN   0.148845
# use_any_social       NaN       NaN       NaN         NaN       NaN        NaN
# Instagram       0.240192  0.316973  0.150970         NaN       NaN  -0.002261
# Snapchat        0.204124  0.206959  0.144338         NaN       NaN  -0.071768
# Twitter         0.306413  0.409673  0.166667         NaN       NaN  -0.057635
# BeReal          1.000000  0.024140  0.023570         NaN       NaN   0.195892
# TikTok          0.024140  1.000000  0.307255         NaN       NaN  -0.303179
# Facebook        0.023570  0.307255  1.000000         NaN       NaN  -0.004075
# Nonelisted           NaN       NaN       NaN         NaN       NaN        NaN
# NotOnAny             NaN       NaN       NaN         NaN       NaN        NaN
# AvgHrsDay       0.195892 -0.303179 -0.004075         NaN       NaN   1.000000
# believeADHD          NaN       NaN       NaN         NaN       NaN        NaN
# age_dx         -0.775879 -0.521684 -0.077172         NaN       NaN  -0.204258
# dx_lic               NaN       NaN       NaN         NaN       NaN        NaN
#
#                 believeADHD    age_dx  dx_lic
# Record ID               NaN -0.361080     NaN
# use_any_social          NaN       NaN     NaN
# Instagram               NaN -0.069421     NaN
# Snapchat                NaN  0.021608     NaN
# Twitter                 NaN -0.358992     NaN
# BeReal                  NaN -0.775879     NaN
# TikTok                  NaN -0.521684     NaN
# Facebook                NaN -0.077172     NaN
# Nonelisted              NaN       NaN     NaN
# NotOnAny                NaN       NaN     NaN
# AvgHrsDay               NaN -0.204258     NaN
# believeADHD             NaN       NaN     NaN
# age_dx                  NaN  1.000000     NaN
# dx_lic                  NaN       NaN     NaN

# %%
#Correlation plot

sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# The df.info() function will give us the basic information about the dataset. 
#For any data, it is good to start by knowing its information. 
#Let’s see how it works with our data.
df.info
# Out:
# <bound method DataFrame.info of     Record ID  Survey Identifier Survey Timestamp use_any_social  \
# 0           1                NaN    4/26/23 16:49            Yes
# 1           2                NaN    4/26/23 16:43            Yes
# 2           3                NaN              NaN            NaN
# 3           4                NaN    4/26/23 18:32            Yes
# 4           5                NaN    4/26/23 20:38            Yes
# 5           6                NaN    4/26/23 21:10            Yes
# 6           7                NaN    4/26/23 21:14            Yes
# 7           8                NaN    4/26/23 21:28            Yes
# 8           9                NaN    4/26/23 21:30            Yes
# 9          10                NaN    4/26/23 21:35            Yes
# 10         11                NaN              NaN            NaN
# 11         12                NaN    4/26/23 22:11            Yes
# 12         13                NaN    4/26/23 23:50            Yes
# 13         14                NaN     4/27/23 3:45            Yes
# 14         15                NaN     4/27/23 5:27            Yes
# 15         16                NaN              NaN            NaN
# 16         17                NaN     4/27/23 7:26            Yes
# 17         18                NaN              NaN            NaN
# 18         19                NaN     4/27/23 9:13            Yes
# 19         20                NaN     4/27/23 9:54            Yes
# 20         21                NaN     4/27/23 9:56            Yes
# 21         22                NaN     4/27/23 9:56            Yes
# 22         23                NaN     4/27/23 9:58            Yes
# 23         24                NaN              NaN            NaN
# 24         25                NaN    4/27/23 10:22            Yes
# 25         26                NaN    4/27/23 10:27            Yes
# 26         27                NaN    4/27/23 10:33            Yes
# 27         28                NaN    4/27/23 10:34            Yes
# 28         29                NaN    4/27/23 10:35            Yes
# 29         30                NaN    4/27/23 11:06            Yes
# 30         31                NaN    4/27/23 11:14            Yes
# 31         32                NaN    4/27/23 11:35            Yes
# 32         33                NaN    4/27/23 11:42            Yes
# 33         34                NaN    4/27/23 11:58            Yes
# 34         35                NaN    4/27/23 13:39            Yes
#
#    Washington_State  Instagram  Snapchat  Twitter  BeReal  TikTok  ...  \
# 0               Yes          1         1        1       0       1  ...
# 1               Yes          1         0        1       0       0  ...
# 2               NaN          0         0        0       0       0  ...
# 3               Yes          1         0        0       0       0  ...
# 4                No          1         0        1       0       1  ...
# 5                No          0         0        0       0       0  ...
# 6                No          1         0        0       0       0  ...
# 7               Yes          1         0        1       0       1  ...
# 8               Yes          0         0        1       0       1  ...
# 9                No          0         0        0       0       0  ...
# 10              NaN          0         0        0       0       0  ...
# 11               No          1         0        0       0       1  ...
# 12               No          1         0        0       0       0  ...
# 13               No          1         0        0       0       0  ...
# 14               No          1         0        1       0       0  ...
# 15              NaN          0         0        0       0       0  ...
# 16               No          0         0        0       0       0  ...
# 17              NaN          0         0        0       0       0  ...
# 18               No          1         0        0       0       0  ...
# 19              Yes          1         1        1       0       0  ...
# 20              Yes          1         1        0       1       0  ...
# 21              Yes          1         0        1       1       1  ...
# 22              Yes          1         1        1       1       0  ...
# 23              NaN          0         0        0       0       0  ...
# 24               No          1         0        0       0       1  ...
# 25              Yes          1         1        0       0       1  ...
# 26              Yes          1         0        1       0       0  ...
# 27              Yes          1         0        1       1       0  ...
# 28               No          1         0        0       0       0  ...
# 29              Yes          1         1        1       0       1  ...
# 30              Yes          1         0        1       0       1  ...
# 31              Yes          1         0        1       1       1  ...
# 32              Yes          1         1        0       0       1  ...
# 33              Yes          1         0        1       0       1  ...
# 34              Yes          1         0        0       0       0  ...
#
#     self_dx  age_dx  dx_lic                                   dx_provider  \
# 0       Yes    28.0     Yes  Telehealth with provider  - location unknown
# 1        No     NaN     NaN                                           NaN
# 2       NaN     NaN     NaN                                           NaN
# 3        No     NaN     NaN                                           NaN
# 4       Yes     NaN     NaN                                           NaN
# 5        No     NaN     NaN                                           NaN
# 6       NaN    44.0     Yes                   Primary Care Provider (PCP)
# 7       Yes     NaN     NaN                                           NaN
# 8        No    27.0     Yes                             Psychiatrist (MD)
# 9        No     NaN     NaN                                           NaN
# 10      NaN     NaN     NaN                                           NaN
# 11      Yes    22.0     Yes                             Psychiatrist (MD)
# 12      Yes     NaN     NaN                                           NaN
# 13      NaN    25.0     Yes                   Primary Care Provider (PCP)
# 14       No     NaN     NaN                                           NaN
# 15      NaN     NaN     NaN                                           NaN
# 16       No     NaN     NaN                                           NaN
# 17      NaN     NaN     NaN                                           NaN
# 18      Yes     NaN     NaN                                           NaN
# 19       No     NaN     NaN                                           NaN
# 20       No     NaN     NaN                                           NaN
# 21      Yes     4.0     Yes                            Psychologist (PhD)
# 22       No     NaN     NaN                                           NaN
# 23      NaN     NaN     NaN                                           NaN
# 24      Yes    27.0     Yes                             Psychiatrist (MD)
# 25       No     NaN     NaN                                           NaN
# 26      Yes     NaN     NaN                                           NaN
# 27       No     NaN     NaN                                           NaN
# 28      Yes     NaN     NaN                                           NaN
# 29       No     NaN     NaN                                           NaN
# 30       No     NaN     NaN                                           NaN
# 31       No     NaN     NaN                                           NaN
# 32      Yes    23.0     Yes                   Primary Care Provider (PCP)
# 33       No    26.0     Yes                             Psychiatrist (MD)
# 34       No     NaN     NaN                                           NaN
#
#                                led_to_dx without_wouldyou rx_for_dx  \
# 0   Web search of symptoms or experience              Yes       Yes
# 1                                    NaN              NaN       NaN
# 2                                    NaN              NaN       NaN
# 3                                    NaN              NaN       NaN
# 4                                    NaN              NaN       NaN
# 5                                    NaN              NaN       NaN
# 6          Parents, Caregiver or Teacher               No        No
# 7                                    NaN              NaN       NaN
# 8     Provider observations or referrals              Yes       Yes
# 9                                    NaN              NaN       NaN
# 10                                   NaN              NaN       NaN
# 11  Web search of symptoms or experience               No       Yes
# 12                                   NaN              NaN       NaN
# 13    Provider observations or referrals               No       Yes
# 14                                   NaN              NaN       NaN
# 15                                   NaN              NaN       NaN
# 16                                   NaN              NaN       NaN
# 17                                   NaN              NaN       NaN
# 18                                   NaN              NaN       NaN
# 19                                   NaN              NaN       NaN
# 20                                   NaN              NaN       NaN
# 21         Parents, Caregiver or Teacher              Yes       Yes
# 22                                   NaN              NaN       NaN
# 23                                   NaN              NaN       NaN
# 24  Web search of symptoms or experience               No        No
# 25                                   NaN              NaN       NaN
# 26                                   NaN              NaN       NaN
# 27                                   NaN              NaN       NaN
# 28                                   NaN              NaN       NaN
# 29                                   NaN              NaN       NaN
# 30                                   NaN              NaN       NaN
# 31                                   NaN              NaN       NaN
# 32                        TikTok content              Yes       Yes
# 33    Provider observations or referrals               No       Yes
# 34                                   NaN              NaN       NaN
#
#                            rx_provider                             led_to_rx  \
# 0   Via Telehealth with local provider  Web search of symptoms or experience
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# 5                                  NaN                                   NaN
# 6                                  NaN                                   NaN
# 7                                  NaN                                   NaN
# 8                         Psychiatrist    Provider observations or referrals
# 9                                  NaN                                   NaN
# 10                                 NaN                                   NaN
# 11                        Psychiatrist                        TikTok content
# 12                                 NaN                                   NaN
# 13         Primary Care Provider (PCP)    Provider observations or referrals
# 14                                 NaN                                   NaN
# 15                                 NaN                                   NaN
# 16                                 NaN                                   NaN
# 17                                 NaN                                   NaN
# 18                                 NaN                                   NaN
# 19                                 NaN                                   NaN
# 20                                 NaN                                   NaN
# 21         Primary Care Provider (PCP)         Parents, Caregiver or Teacher
# 22                                 NaN                                   NaN
# 23                                 NaN                                   NaN
# 24                                 NaN                                   NaN
# 25                                 NaN                                   NaN
# 26                                 NaN                                   NaN
# 27                                 NaN                                   NaN
# 28                                 NaN                                   NaN
# 29                                 NaN                                   NaN
# 30                                 NaN                                   NaN
# 31                                 NaN                                   NaN
# 32         Primary Care Provider (PCP)                        TikTok content
# 33                        Psychiatrist    Provider observations or referrals
# 34                                 NaN                                   NaN
#
#      Complete?
# 0     Complete
# 1     Complete
# 2   Incomplete
# 3     Complete
# 4     Complete
# 5     Complete
# 6     Complete
# 7     Complete
# 8     Complete
# 9     Complete
# 10  Incomplete
# 11    Complete
# 12    Complete
# 13    Complete
# 14    Complete
# 15  Incomplete
# 16    Complete
# 17  Incomplete
# 18    Complete
# 19    Complete
# 20    Complete
# 21    Complete
# 22    Complete
# 23  Incomplete
# 24    Complete
# 25    Complete
# 26    Complete
# 27    Complete
# 28    Complete
# 29    Complete
# 30    Complete
# 31    Complete
# 32    Complete
# 33    Complete
# 34    Complete
#
# [35 rows x 30 columns]>

# %%
# describe() provides descriptive statistics of the data 
df.describe()
# Out:
#        Record ID  Survey Identifier  Instagram  Snapchat    Twitter  \
# count  35.000000                0.0  35.000000  35.00000  35.000000
# mean   18.000000                NaN   0.742857   0.20000   0.428571
# std    10.246951                NaN   0.443440   0.40584   0.502096
# min     1.000000                NaN   0.000000   0.00000   0.000000
# 25%     9.500000                NaN   0.500000   0.00000   0.000000
# 50%    18.000000                NaN   1.000000   0.00000   0.000000
# 75%    26.500000                NaN   1.000000   0.00000   1.000000
# max    35.000000                NaN   1.000000   1.00000   1.000000
#
#           BeReal     TikTok   Facebook  Nonelisted  NotOnAny  AvgHrsDay  \
# count  35.000000  35.000000  35.000000        35.0      35.0  30.000000
# mean    0.142857   0.371429   0.571429         0.0       0.0   2.733333
# std     0.355036   0.490241   0.502096         0.0       0.0   2.941186
# min     0.000000   0.000000   0.000000         0.0       0.0   0.500000
# 25%     0.000000   0.000000   0.000000         0.0       0.0   1.000000
# 50%     0.000000   0.000000   1.000000         0.0       0.0   2.000000
# 75%     0.000000   1.000000   1.000000         0.0       0.0   3.000000
# max     1.000000   1.000000   1.000000         0.0       0.0  15.000000
#
#           age_dx
# count   9.000000
# mean   25.111111
# std    10.203485
# min     4.000000
# 25%    23.000000
# 50%    26.000000
# 75%    27.000000
# max    44.000000

# %% [markdown]
# ## Missing and Null Values Cleaning

# %%
#Find null values

df.isnull().sum()
# Out:
# Record ID               0
# Survey Timestamp        5
# use_any_social          5
# Washington_State        5
# Instagram               0
# Snapchat                0
# Twitter                 0
# BeReal                  0
# TikTok                  0
# Facebook                0
# Nonelisted              0
# NotOnAny                0
# SocMedMostUsed          0
# AvgHrsDay               5
# Age                     5
# ADHDinFYP              22
# ADHDcontentsupports    23
# believeADHD            25
# dxADHD                  5
# self_dx                 7
# age_dx                 26
# dx_lic                 26
# dx_provider            26
# led_to_dx              26
# without_wouldyou       26
# rx_for_dx              26
# rx_provider            28
# led_to_rx              28
# Complete?               0
# dtype: int64

# %%
# null data displayed as percentages 
df.isnull().sum()/len(df)

# %%
# show columsn with highest percentage of missing data first 
df.isnull().sum().sort_values(ascending = False)/len(df)
# Out:
# led_to_rx              0.800000
# rx_provider            0.800000
# dx_provider            0.742857
# led_to_dx              0.742857
# age_dx                 0.742857
# dx_lic                 0.742857
# rx_for_dx              0.742857
# without_wouldyou       0.742857
# believeADHD            0.714286
# ADHDcontentsupports    0.657143
# ADHDinFYP              0.628571
# self_dx                0.200000
# dxADHD                 0.142857
# Washington_State       0.142857
# use_any_social         0.142857
# AvgHrsDay              0.142857
# Survey Timestamp       0.142857
# Age                    0.142857
# Record ID              0.000000
# SocMedMostUsed         0.000000
# NotOnAny               0.000000
# Nonelisted             0.000000
# Facebook               0.000000
# TikTok                 0.000000
# BeReal                 0.000000
# Twitter                0.000000
# Snapchat               0.000000
# Instagram              0.000000
# Complete?              0.000000
# dtype: float64

# %% [markdown]
# ## Data Cleaning

# %%
df['Street Number'] = df['Street Number'].replace(0, np.nan)

# %%
#Replace null values

df.replace(np.nan,'0',inplace = True)

#Check the changes now
df.isnull().sum()
# Out:
# Record ID              0
# Survey Identifier      0
# Survey Timestamp       0
# use_any_social         0
# Washington_State       0
# Instagram              0
# Snapchat               0
# Twitter                0
# BeReal                 0
# TikTok                 0
# Facebook               0
# Nonelisted             0
# NotOnAny               0
# SocMedMostUsed         0
# AvgHrsDay              0
# Age                    0
# ADHDinFYP              0
# ADHDcontentsupports    0
# believeADHD            0
# dxADHD                 0
# self_dx                0
# age_dx                 0
# dx_lic                 0
# dx_provider            0
# led_to_dx              0
# without_wouldyou       0
# rx_for_dx              0
# rx_provider            0
# led_to_rx              0
# Complete?              0
# dtype: int64

# %%
# Missing values
df.isna().sum()
# Out:
# Record ID               0
# Survey Identifier      35
# Survey Timestamp        5
# use_any_social          5
# Washington_State        5
# Instagram               0
# Snapchat                0
# Twitter                 0
# BeReal                  0
# TikTok                  0
# Facebook                0
# Nonelisted              0
# NotOnAny                0
# SocMedMostUsed          0
# AvgHrsDay               5
# Age                     5
# ADHDinFYP              22
# ADHDcontentsupports    23
# believeADHD            25
# dxADHD                  5
# self_dx                 7
# age_dx                 26
# dx_lic                 26
# dx_provider            26
# led_to_dx              26
# without_wouldyou       26
# rx_for_dx              26
# rx_provider            28
# led_to_rx              28
# Complete?               0
# dtype: int64

# %%
#Find the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
#unique values

df['rowname2'].unique()

df['rowname3'].unique()

df['rowname4'].unique()

# %%
#Plot the unique values

sns.countplot(df['rowname2']).unique()

# %%
df.columns
# Out:
# Index(['Record ID', 'Survey Identifier', 'Survey Timestamp',
#        'The following survey has been created by students enrolled in the Masters of Information Management IMT 570 course at the University of Washington. (https://ischool.uw.edu/programs/msim)  The survey was created as part of a project examining social media use and diagnosis of a health condition. You may have received this link while engaging on a social media platform or by being sent the link directly from someone you know.    The survey asks questions which might involve personal or sensitive information. No identifiable information is being collected and all answers will be completely anonymous. There are no additional follow up requirements.  This is a single survey.    Data collected will be analyzed to examine associations between a health condition and social media use. No information or data from this survey will be published or shared outside of the scope of the course (IMT 570: Data Driven Organizational Problem Solving for Information Management Professionals ). If you have additional questions related to this survey, you can contact us at: uwsocialmediasurvey@gmail.com  We believe there are no risks associated with completion of this survey as no information can or will be traced to you or your answers.   There is no cost to complete this survey nor are we providing any compensation for completion.  There is no direct benefit to you for completing the survey. Completion should take no more than 5 minutes of your time. The alternative to completing this survey is to not complete the survey.  Thank you for your participation in this quick survey! If you wish to continue, please select 'Yes' below. (choice=Yes -  I wish to complete this quick survey)',
#        'The following survey has been created by students enrolled in the Masters of Information Management IMT 570 course at the University of Washington. (https://ischool.uw.edu/programs/msim)  The survey was created as part of a project examining social media use and diagnosis of a health condition. You may have received this link while engaging on a social media platform or by being sent the link directly from someone you know.    The survey asks questions which might involve personal or sensitive information. No identifiable information is being collected and all answers will be completely anonymous. There are no additional follow up requirements.  This is a single survey.    Data collected will be analyzed to examine associations between a health condition and social media use. No information or data from this survey will be published or shared outside of the scope of the course (IMT 570: Data Driven Organizational Problem Solving for Information Management Professionals ). If you have additional questions related to this survey, you can contact us at: uwsocialmediasurvey@gmail.com  We believe there are no risks associated with completion of this survey as no information can or will be traced to you or your answers.   There is no cost to complete this survey nor are we providing any compensation for completion.  There is no direct benefit to you for completing the survey. Completion should take no more than 5 minutes of your time. The alternative to completing this survey is to not complete the survey.  Thank you for your participation in this quick survey! If you wish to continue, please select 'Yes' below. (choice=No - I do not wish to continue)',
#        'Complete?', 'Survey Timestamp.1', 'Do you use any social media?',
#        'Do you live in Washington State? ',
#        'What social media platforms do you currently use? (select all that apply)   (choice=Instagram)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=Snapchat)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=Twitter)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=BeReal)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=TikTok)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=Facebook)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=None listed)',
#        'What social media platforms do you currently use? (select all that apply)   (choice=Not a user on any social media platforms)',
#        'Which social media platform do you spend the most hours using per week?  ',
#        'Approximately how many hours per day on average do you spend on this platform?',
#        'Which age range do you fit into?',
#        'Do you receive content related to ADHD in your FYP  (For you page) ?',
#        'Does ADHD content on TikTok support your experience?   ',
#        'Do you believe you have ADHD?', 'Do you have a diagnosis of ADHD?',
#        'Would you self-diagnose or have you self-diagnosed with ADHD?  ',
#        'At what age were you diagnosed with ADHD?   ',
#        'Were you diagnosed by a licensed professional?',
#        'What best describes the type of provider who provided your diagnosis?  ',
#        'What led you to seek diagnosis?  ',
#        'Do you feel that without [ledtodx], you would not have sought diagnosis?   ',
#        'Have you received a prescription to treat your ADHD?  ',
#        'What best describes the type of provider who provided your prescription?  ',
#        'What led you to seek a prescription treatment?  ', 'Complete?.1'],
#       dtype='object')

# %%
df.rowname
